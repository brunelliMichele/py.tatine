# %% [markdown]
# PRECISION@K PER MODEL
# - EfficientNetB0 =
# - EfficientNetB4 =
# - EfficientNet_merged =
# - ResNet 50 =
# - Dino =
# - CLIP =
# - VGG16 =

# %% [markdown]
# ACCURACY PER MODEL
# - EfficientNetB0 =
# - EfficientNetB4 =
# - EfficientNet_merged =
# - ResNet 50 =
# - Dino =
# - CLIP =
# - VGG16 =
