# %% [markdown]
# PRECISION@K PER MODEL
# - EfficientNetB0 = 0.72
# - EfficientNetB4 = 0.73
# - EfficientNet_merged =
# - ResNet 50 =
# - Dino =
# - CLIP = 0.835
# - CLIP_fine_tuned = 0.05
# - VGG16 =

# %% [markdown]
# ACCURACY PER MODEL
# - EfficientNetB0 = 0.95
# - EfficientNetB4 = 0.95
# - EfficientNet_merged =
# - ResNet 50 =
# - Dino =
# - CLIP = 1.00
# - CLIP_fine_tuned = 0.05
# - VGG16 =

# %% [markdown]
# COMPETITION DAY EVALUATION
#
# - EfficientNetB0 =
# - EfficientNetB4 =
# - EfficientNet_merged =
# - ResNet 50 =
# - Dino =
# - CLIP =
# - CLIP_fine_tuned =
# - VGG16 =
